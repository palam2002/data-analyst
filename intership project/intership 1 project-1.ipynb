# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('/Users/palammysurareddy/Downloads/intership project 11:08:2025 /Dataset  - Dataset .csv')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karak�_y
# 9547                                   Ko��uyolu
# 9548                                 Kuru�_e��me
# 9549                                 Kuru�_e��me
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karak�_y, ��stanbul   28.977392
# 9547                               Ko��uyolu, ��stanbul   29.041297
# 9548                             Kuru�_e��me, ��stanbul   29.034640
# 9549                             Kuru�_e��me, ��stanbul   29.036019
# 9550                                    Moda, ��stanbul   29.026016
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9546  41.022793                           Turkish  ...  Turkish Lira(TL)
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548  41.055817            Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549  41.057979                   Restaurant Cafe  ...  Turkish Lira(TL)
# 9550  40.984776                              Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [9551 rows x 21 columns]

# %%
print(df.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
print("Columns in dataset:", df.columns)
# Out:
# Columns in dataset: Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
cuisine_column = 'Cuisines'
cuisine_column
# Out:
# 'Cuisines'

# %%
if cuisine_column not in df.columns:
    raise ValueError(f"The dataset does not contain a '{cuisine_column}' column. Please check column names.")

# %%
cuisine_counts = df[cuisine_column].value_counts()
cuisine_counts
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %%
top_cuisines = cuisine_counts.head(3)
top_cuisines
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
top_cuisines
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
total_restaurants = len(df)
top_cuisines_percentage = (top_cuisines / total_restaurants) * 100
top_cuisines_percentage
# Out:
# Cuisines
# North Indian             9.800021
# North Indian, Chinese    5.350225
# Chinese                  3.706418
# Name: count, dtype: float64

# %%
result = pd.DataFrame({
    'Cuisine': top_cuisines.index,
    'Count': top_cuisines.values,
    'Percentage': top_cuisines_percentage.round(2)
})
result
# Out:
#                                      Cuisine  Count  Percentage
# Cuisines
# North Indian                    North Indian    936        9.80
# North Indian, Chinese  North Indian, Chinese    511        5.35
# Chinese                              Chinese    354        3.71

# %%
print("Top 3 Cuisines and Their Percentages:")
print(result)
# Out:
# Top 3 Cuisines and Their Percentages:
#                                      Cuisine  Count  Percentage
# Cuisines
# North Indian                    North Indian    936        9.80
# North Indian, Chinese  North Indian, Chinese    511        5.35
# Chinese                              Chinese    354        3.71

# %%
city_column = "City"  # Change if your dataset uses a different name
rating_column = "Aggregate rating"

# %%
for col in [city_column, rating_column]:
    if col not in df.columns:
        raise ValueError(f"The dataset does not contain a '{col}' column.")

# %%
city_counts = df[city_column].value_counts()
top_city_by_count = city_counts.idxmax()
top_city_count = city_counts.max()

# %%
avg_rating_by_city = df.groupby(city_column)[rating_column].mean()
avg_rating_by_city
# Out:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ��stanbul          4.292857
# Name: Aggregate rating, Length: 141, dtype: float64

# %%
top_city_by_rating = avg_rating_by_city.idxmax()
top_avg_rating = avg_rating_by_city.max()
top_city_by_rating
# Out:
# 'Inner City'

# %%
top_avg_rating
# Out:
# 4.9

# %%
print(f"City with the highest number of restaurants: {top_city_by_count} ({top_city_count} restaurants)")
print("\nAverage rating for restaurants in each city:")
print(avg_rating_by_city.round(2))
print(f"\nCity with the highest average rating: {top_city_by_rating} ({top_avg_rating:.2f})")
# Out:
# City with the highest number of restaurants: New Delhi (5473 restaurants)
#
# Average rating for restaurants in each city:
# City
# Abu Dhabi          4.30
# Agra               3.96
# Ahmedabad          4.16
# Albany             3.56
# Allahabad          3.40
#                    ...
# Weirton            3.90
# Wellington City    4.25
# Winchester Bay     3.20
# Yorkton            3.30
# ��stanbul          4.29
# Name: Aggregate rating, Length: 141, dtype: float64
#
# City with the highest average rating: Inner City (4.90)

# %%
price_column = "Price range"
price_column
# Out:
# 'Price range'

# %%
if price_column not in df.columns:
    raise ValueError(f"The dataset does not contain a '{price_column}' column.")

# %%
price_counts = df[price_column].value_counts().sort_index()
price_counts
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
total_restaurants = len(df)
price_percentages = (price_counts / total_restaurants) * 100
total_restaurants
price_percentages
# Out:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64

# %%
price_percentages
# Out:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64

# %%
print("Percentage of restaurants in each price range category:")
print(price_percentages.round(2))
# Out:
# Percentage of restaurants in each price range category:
# Price range
# 1    46.53
# 2    32.59
# 3    14.74
# 4     6.14
# Name: count, dtype: float64

# %%
plt.figure(figsize=(8,5))
price_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Distribution of Price Ranges Among Restaurants")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")
plt.xticks(rotation=0)
plt.show()

# %%
online_delivery_col = "Has Online delivery"   # Change if your dataset uses another name
rating_col = "Aggregate rating"
online_delivery_col
rating_col
# Out:
# 'Aggregate rating'

# %%
for col in [online_delivery_col, rating_col]:
    if col not in df.columns:
        raise ValueError(f"The dataset does not contain a '{col}' column.")

# %%
delivery_counts = df[online_delivery_col].value_counts()
total_restaurants = len(df)
percentage_online_delivery = (delivery_counts.get("Yes", 0) / total_restaurants) * 100
delivery_counts
total_restaurants
# Out:
# 9551

# %%
delivery_counts
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
total_restaurants
# Out:
# 9551

# %%
percentage_online_delivery
# Out:
# 25.662234321013504

# %%
avg_rating_comparison = df.groupby(online_delivery_col)[rating_col].mean().round(2)

# Output results
print(f"Percentage of restaurants with online delivery: {percentage_online_delivery:.2f}%")
print("\nAverage Ratings (Online Delivery vs No):")
print(avg_rating_comparison)
# Out:
# Percentage of restaurants with online delivery: 25.66%
#
# Average Ratings (Online Delivery vs No):
# Has Online delivery
# No     2.47
# Yes    3.25
# Name: Aggregate rating, dtype: float64

# %%
rating_col = "Aggregate rating"  
votes_col = "Votes" 
rating_col
votes_col
# Out:
# 'Votes'

# %%
for col in [rating_col, votes_col]:
    if col not in df.columns:
        raise ValueError(f"The dataset does not contain a '{col}' column.")

# %%
rating_counts = df[rating_col].value_counts().sort_index()
rating_counts
# Out:
# Aggregate rating
# 0.0    2148
# 1.8       1
# 1.9       2
# 2.0       7
# 2.1      15
# 2.2      27
# 2.3      47
# 2.4      87
# 2.5     110
# 2.6     191
# 2.7     250
# 2.8     315
# 2.9     381
# 3.0     468
# 3.1     519
# 3.2     522
# 3.3     483
# 3.4     498
# 3.5     480
# 3.6     458
# 3.7     427
# 3.8     400
# 3.9     335
# 4.0     266
# 4.1     274
# 4.2     221
# 4.3     174
# 4.4     144
# 4.5      95
# 4.6      78
# 4.7      42
# 4.8      25
# 4.9      61
# Name: count, dtype: int64

# %%
most_common_rating = rating_counts.idxmax()
most_common_count = rating_counts.max()
most_common_count
most_common_rating
# Out:
# 0.0

# %%
most_common_rating
# Out:
# 0.0

# %%
avg_votes = df[votes_col].mean()
avg_votes
# Out:
# 156.909747670401

# %%
print("Distribution of Aggregate Ratings:")
print(rating_counts)
print(f"\nMost common rating: {most_common_rating} (count: {most_common_count})")
print(f"\nAverage number of votes per restaurant: {avg_votes:.2f}")
# Out:
# Distribution of Aggregate Ratings:
# Aggregate rating
# 0.0    2148
# 1.8       1
# 1.9       2
# 2.0       7
# 2.1      15
# 2.2      27
# 2.3      47
# 2.4      87
# 2.5     110
# 2.6     191
# 2.7     250
# 2.8     315
# 2.9     381
# 3.0     468
# 3.1     519
# 3.2     522
# 3.3     483
# 3.4     498
# 3.5     480
# 3.6     458
# 3.7     427
# 3.8     400
# 3.9     335
# 4.0     266
# 4.1     274
# 4.2     221
# 4.3     174
# 4.4     144
# 4.5      95
# 4.6      78
# 4.7      42
# 4.8      25
# 4.9      61
# Name: count, dtype: int64
#
# Most common rating: 0.0 (count: 2148)
#
# Average number of votes per restaurant: 156.91

# %%
cuisine_col = "Cuisines"         
rating_col = "Aggregate rating"
cuisine_col,rating_col
# Out:
# ('Cuisines', 'Aggregate rating')

# %%
for col in [cuisine_col, rating_col]:
    if col not in df.columns:
        raise ValueError(f"The dataset does not contain a '{col}' column.")

# %%
cuisine_combinations = df[cuisine_col].value_counts().head(10)
cuisine_combinations
# Out:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
avg_rating_by_combo = df.groupby(cuisine_col)[rating_col].mean().sort_values(ascending=False)
avg_rating_by_combo
# Out:
# Cuisines
# Italian, Deli                     4.9
# Hawaiian, Seafood                 4.9
# American, Sandwich, Tea           4.9
# Continental, Indian               4.9
# European, Asian, Indian           4.9
#                                  ...
# Fast Food, Desserts, Beverages    0.0
# Fast Food, Chinese, Burger        0.0
# Cafe, French                      0.0
# Seafood, Mughlai, North Indian    0.0
# Fast Food, Mughlai, Armenian      0.0
# Name: Aggregate rating, Length: 1825, dtype: float64

# %%
print("Top 10 Most Common Cuisine Combinations:")
print(cuisine_combinations)
print("\nAverage Ratings for Cuisine Combinations:")
print(avg_rating_by_combo.round(2))
# Out:
# Top 10 Most Common Cuisine Combinations:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64
#
# Average Ratings for Cuisine Combinations:
# Cuisines
# Italian, Deli                     4.9
# Hawaiian, Seafood                 4.9
# American, Sandwich, Tea           4.9
# Continental, Indian               4.9
# European, Asian, Indian           4.9
#                                  ...
# Fast Food, Desserts, Beverages    0.0
# Fast Food, Chinese, Burger        0.0
# Cafe, French                      0.0
# Seafood, Mughlai, North Indian    0.0
# Fast Food, Mughlai, Armenian      0.0
# Name: Aggregate rating, Length: 1825, dtype: float64

# %%
lat_col = "Latitude"   
lon_col = "Longitude"
lat_col,lon_col
# Out:
# ('Latitude', 'Longitude')

# %%
for col in [lat_col, lon_col]:
    if col not in df.columns:
        raise ValueError(f"The dataset does not contain a '{col}' column.")

# %%
df = df.dropna(subset=[lat_col, lon_col])
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karak�_y
# 9547                                   Ko��uyolu
# 9548                                 Kuru�_e��me
# 9549                                 Kuru�_e��me
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karak�_y, ��stanbul   28.977392
# 9547                               Ko��uyolu, ��stanbul   29.041297
# 9548                             Kuru�_e��me, ��stanbul   29.034640
# 9549                             Kuru�_e��me, ��stanbul   29.036019
# 9550                                    Moda, ��stanbul   29.026016
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9546  41.022793                           Turkish  ...  Turkish Lira(TL)
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548  41.055817            Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549  41.057979                   Restaurant Cafe  ...  Turkish Lira(TL)
# 9550  40.984776                              Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [9551 rows x 21 columns]

# %%
plt.figure(figsize=(12, 5))
plt.scatter(df[lon_col], df[lat_col], alpha=0.5, s=10, color="blue", edgecolors='none')
plt.title("Restaurant Locations")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(True)
plt.show()

# %%
name_col = "Restaurant Name"     # Change if different
rating_col = "Aggregate rating"  # Change if different
votes_col = "Votes"
name_col,rating_col,votes_col
# Out:
# ('Restaurant Name', 'Aggregate rating', 'Votes')

# %%
for col in [name_col, rating_col, votes_col]:
    if col not in df.columns:
        raise ValueError(f"The dataset does not contain a '{col}' column.")

# %%
chain_counts = df[name_col].value_counts()
restaurant_chains = chain_counts[chain_counts > 1]
chain_counts,restaurant_chains
# Out:
# (Restaurant Name
#  Cafe Coffee Day             83
#  Domino's Pizza              79
#  Subway                      63
#  Green Chick Chop            51
#  McDonald's                  48
#                              ..
#  Odeon Social                 1
#  Johnny Rockets               1
#  House of Commons             1
#  HotMess                      1
#  Walter's Coffee Roastery     1
#  Name: count, Length: 7446, dtype: int64,
#  Restaurant Name
#  Cafe Coffee Day       83
#  Domino's Pizza        79
#  Subway                63
#  Green Chick Chop      51
#  McDonald's            48
#                        ..
#  Town Hall              2
#  Halki Aanch            2
#  Snack Junction         2
#  Delhi Biryani Hut      2
#  Beliram Degchiwala     2
#  Name: count, Length: 734, dtype: int64)

# %%
chain_data = df[df[name_col].isin(restaurant_chains.index)]
chain_analysis = chain_data.groupby(name_col).agg({
    rating_col: "mean",
    votes_col: "mean",
    name_col: "count"
}).rename(columns={name_col: "Number of Outlets"})
chain_data
# Out:
#       Restaurant ID   Restaurant Name  Country Code              City  \
# 5          18189371      Din Tai Fung           162  Mandaluyong City
# 10          6309903  Silantro Fil-Mex           162        Pasig City
# 12          6318433  Silantro Fil-Mex           162       Quezon City
# 35          6601589        Coco Bambu            30         Bras�_lia
# 39          6600427        Coco Bambu            30         Bras�_lia
# ...             ...               ...           ...               ...
# 9517        6001980       Timboo Cafe           208            Ankara
# 9528        6003668       Timboo Cafe           208            Ankara
# 9534        6004089       D�_vero��lu           208            Ankara
# 9535        6000921       D�_vero��lu           208            Ankara
# 9538        5901782         Starbucks           208         ��stanbul
#
#                                                 Address  \
# 5     Ground Floor, Mega Fashion Hall, SM Megamall, ...
# 10         75 East Capitol Drive, Kapitolyo, Pasig City
# 12    Second Floor, UP Town Center, Katipunan Avenue...
# 35    Bras�_lia Shopping - Piso 2, SCN 5, Bloco A, A...
# 39    SCES, Trecho 2, Conjunto 13/36, Setor de Clube...
# ...                                                 ...
# 9517  Armada AVM, Kat -1, Eski��ehir Yolu, No 6, Yen...
# 9528  Kentpark AVM, Kat -1, Mustafa Kemal Mahallesi,...
# 9534  Maltepe Mahallesi, Gen�_lik Caddesi, No 28, �a...
# 9535  ��mitk�_y Mahallesi, 2432. Cadde (8. Cadde), N...
# 9538  Bebek Mahallesi, Cevdetpa��a Caddesi, No 30/A,...
#
#                                     Locality  \
# 5     SM Megamall, Ortigas, Mandaluyong City
# 10                                 Kapitolyo
# 12      UP Town Center, Diliman, Quezon City
# 35             Bras�_lia Shopping, Asa Norte
# 39            Setor De Clubes Esportivos Sul
# ...                                      ...
# 9517  Armada AVM, S�_���_t�_z�_, Yenimahalle
# 9528   Kentpark AVM, ��niversiteler, �ankaya
# 9534                                 Maltepe
# 9535                               ��mitk�_y
# 9538                                   Bebek
#
#                                        Locality Verbose   Longitude  \
# 5     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056314
# 10                                Kapitolyo, Pasig City  121.057916
# 12    UP Town Center, Diliman, Quezon City, Quezon City  121.075419
# 35             Bras�_lia Shopping, Asa Norte, Bras�_lia  -47.889000
# 39            Setor De Clubes Esportivos Sul, Bras�_lia  -47.868500
# ...                                                 ...         ...
# 9517     Armada AVM, S�_���_t�_z�_, Yenimahalle, Ankara   32.809247
# 9528      Kentpark AVM, ��niversiteler, �ankaya, Ankara   32.776255
# 9534                                    Maltepe, Ankara   32.842742
# 9535                                  ��mitk�_y, Ankara   32.701775
# 9538                                   Bebek, ��stanbul   29.043734
#
#        Latitude                        Cuisines  ...            Currency  \
# 5     14.583764                         Chinese  ...    Botswana Pula(P)
# 10    14.567689               Filipino, Mexican  ...    Botswana Pula(P)
# 12    14.649503               Filipino, Mexican  ...    Botswana Pula(P)
# 35   -15.786500                   International  ...  Brazilian Real(R$)
# 39   -15.819000                   International  ...  Brazilian Real(R$)
# ...         ...                             ...  ...                 ...
# 9517  39.913206                            Cafe  ...    Turkish Lira(TL)
# 9528  39.908957                            Cafe  ...    Turkish Lira(TL)
# 9534  39.922536  Kebab, Desserts, Turkish Pizza  ...    Turkish Lira(TL)
# 9535  39.891564  Kebab, Desserts, Turkish Pizza  ...    Turkish Lira(TL)
# 9538  41.077696                            Cafe  ...    Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 5                   No                  No                No
# 10                  No                  No                No
# 12                  No                  No                No
# 35                  No                  No                No
# 39                  No                  No                No
# ...                ...                 ...               ...
# 9517                No                  No                No
# 9528                No                  No                No
# 9534                No                  No                No
# 9535                No                  No                No
# 9538                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 5                      No           3               4.4         Green
# 10                     No           3               4.9    Dark Green
# 12                     No           3               4.8    Dark Green
# 35                     No           4               4.2         Green
# 39                     No           4               4.9    Dark Green
# ...                   ...         ...               ...           ...
# 9517                   No           3               4.2         Green
# 9528                   No           3               4.2         Green
# 9534                   No           3               4.4         Green
# 9535                   No           3               4.2         Green
# 9538                   No           2               4.9    Dark Green
#
#      Rating text Votes
# 5      Very Good   336
# 10     Excellent  1070
# 12     Excellent   294
# 35     Very Good    17
# 39     Excellent    30
# ...          ...   ...
# 9517   Very Good   134
# 9528   Very Good    79
# 9534   Very Good   131
# 9535   Very Good   152
# 9538   Excellent  1042
#
# [2839 rows x 21 columns]

# %%
chain_analysis
# Out:
#                       Aggregate rating       Votes  Number of Outlets
# Restaurant Name
# 10 Downing Street             4.000000  335.000000                  2
# 221 B Baker Street            3.366667   71.666667                  3
# 34 Parkstreet Lane            3.050000   15.500000                  2
# 34, Chowringhee Lane          2.791667   64.750000                 12
# 4700BC Popcorn                3.500000   88.000000                  2
# ...                                ...         ...                ...
# Zaika                         2.850000   61.250000                  4
# Zaika Kathi Rolls             1.500000    8.000000                  2
# Zizo                          3.866667  457.000000                  3
# Zooby's Kitchen               3.150000   26.000000                  2
# bu��no                        3.750000   58.500000                  2
#
# [734 rows x 3 columns]

# %%
rating_col
# Out:
# 'Aggregate rating'

# %%
votes_col
# Out:
# 'Votes'

# %%
chain_analysis = chain_analysis.sort_values(by="Number of Outlets", ascending=False)
chain_analysis
# Out:
#                   Aggregate rating       Votes  Number of Outlets
# Restaurant Name
# Cafe Coffee Day           2.419277   29.253012                 83
# Domino's Pizza            2.740506   84.088608                 79
# Subway                    2.907937   97.206349                 63
# Green Chick Chop          2.672549   18.901961                 51
# McDonald's                3.339583  110.229167                 48
# ...                            ...         ...                ...
# Gullu's                   3.000000   57.000000                  2
# Gulab                     2.950000   25.500000                  2
# Grover Sweets             1.550000    5.000000                  2
# Grillz                    2.350000   52.000000                  2
# bu��no                    3.750000   58.500000                  2
#
# [734 rows x 3 columns]

# %%
print("Restaurant Chains Found:")
print(restaurant_chains)
print("\nRatings and Popularity of Restaurant Chains:")
print(chain_analysis.round(2))
# Out:
# Restaurant Chains Found:
# Restaurant Name
# Cafe Coffee Day       83
# Domino's Pizza        79
# Subway                63
# Green Chick Chop      51
# McDonald's            48
#                       ..
# Town Hall              2
# Halki Aanch            2
# Snack Junction         2
# Delhi Biryani Hut      2
# Beliram Degchiwala     2
# Name: count, Length: 734, dtype: int64
#
# Ratings and Popularity of Restaurant Chains:
#                       Aggregate rating   Votes  Number of Outlets
# Restaurant Name
# 10 Downing Street                 4.00  335.00                  2
# 221 B Baker Street                3.37   71.67                  3
# 34 Parkstreet Lane                3.05   15.50                  2
# 34, Chowringhee Lane              2.79   64.75                 12
# 4700BC Popcorn                    3.50   88.00                  2
# ...                                ...     ...                ...
# Zaika                             2.85   61.25                  4
# Zaika Kathi Rolls                 1.50    8.00                  2
# Zizo                              3.87  457.00                  3
# Zooby's Kitchen                   3.15   26.00                  2
# bu��no                            3.75   58.50                  2
#
# [734 rows x 3 columns]

# %%
plt.figure(figsize=(10, 5))
chain_analysis[rating_col].plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Average Ratings of Restaurant Chains")
plt.xlabel("Restaurant Chain")
plt.ylabel("Average Rating")
plt.xticks(rotation=75)
plt.tight_layout()
plt.show()

# %%
import re 
from collections import Counter

review_col = "Review Text"      
rating_col = "Aggregate rating"

# %%
import random

sample_reviews = [
    "Great food and service!",
    "Average experience, nothing special.",
    "Will definitely come back again!",
    "Food was cold and service was slow.",
    "Excellent taste and friendly staff."
]

# Add a fake review column
df["Review"] = [random.choice(sample_reviews) for _ in range(len(df))]

review_col = "Review"
rating_col = "Aggregate rating"

# %%
print(df.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Review'],
#       dtype='object')

# %%
for col in [review_col, rating_col]:
    if col not in df.columns:
        raise ValueError(f"The dataset does not contain a '{col}' column.")

# %%
df = df.dropna(subset=[review_col])

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z\s]", "", text)  # remove punctuation/numbers
    return text

# %%
df["cleaned_review"] = df[review_col].apply(clean_text)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karak�_y
# 9547                                   Ko��uyolu
# 9548                                 Kuru�_e��me
# 9549                                 Kuru�_e��me
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karak�_y, ��stanbul   28.977392
# 9547                               Ko��uyolu, ��stanbul   29.041297
# 9548                             Kuru�_e��me, ��stanbul   29.034640
# 9549                             Kuru�_e��me, ��stanbul   29.036019
# 9550                                    Moda, ��stanbul   29.026016
#
#        Latitude                          Cuisines  ...  Has Online delivery  \
# 0     14.565443        French, Japanese, Desserts  ...                   No
# 1     14.553708                          Japanese  ...                   No
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...                   No
# 3     14.585318                   Japanese, Sushi  ...                   No
# 4     14.584450                  Japanese, Korean  ...                   No
# ...         ...                               ...  ...                  ...
# 9546  41.022793                           Turkish  ...                   No
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...                   No
# 9548  41.055817            Italian, World Cuisine  ...                   No
# 9549  41.057979                   Restaurant Cafe  ...                   No
# 9550  40.984776                              Cafe  ...                   No
#
#      Is delivering now Switch to order menu Price range Aggregate rating  \
# 0                   No                   No           3              4.8
# 1                   No                   No           3              4.5
# 2                   No                   No           4              4.4
# 3                   No                   No           4              4.9
# 4                   No                   No           4              4.8
# ...                ...                  ...         ...              ...
# 9546                No                   No           3              4.1
# 9547                No                   No           3              4.2
# 9548                No                   No           4              3.7
# 9549                No                   No           4              4.0
# 9550                No                   No           2              4.0
#
#      Rating color  Rating text  Votes                                Review  \
# 0      Dark Green    Excellent    314   Excellent taste and friendly staff.
# 1      Dark Green    Excellent    591  Average experience, nothing special.
# 2           Green    Very Good    270  Average experience, nothing special.
# 3      Dark Green    Excellent    365  Average experience, nothing special.
# 4      Dark Green    Excellent    229   Food was cold and service was slow.
# ...           ...          ...    ...                                   ...
# 9546        Green    Very Good    788      Will definitely come back again!
# 9547        Green    Very Good   1034               Great food and service!
# 9548       Yellow         Good    661      Will definitely come back again!
# 9549        Green    Very Good    901   Food was cold and service was slow.
# 9550        Green    Very Good    591  Average experience, nothing special.
#
#                           cleaned_review
# 0     excellent taste and friendly staff
# 1     average experience nothing special
# 2     average experience nothing special
# 3     average experience nothing special
# 4     food was cold and service was slow
# ...                                  ...
# 9546     will definitely come back again
# 9547              great food and service
# 9548     will definitely come back again
# 9549  food was cold and service was slow
# 9550  average experience nothing special
#
# [9551 rows x 23 columns]

# %%
positive_words = ["good", "great", "amazing", "excellent", "delicious", "friendly", "perfect", "love", "nice", "tasty"]
negative_words = ["bad", "poor", "worst", "terrible", "awful", "slow", "disappointing", "hate", "rude", "bland"]
negative_words,positive_words
# Out:
# (['bad',
#   'poor',
#   'worst',
#   'terrible',
#   'awful',
#   'slow',
#   'disappointing',
#   'hate',
#   'rude',
#   'bland'],
#  ['good',
#   'great',
#   'amazing',
#   'excellent',
#   'delicious',
#   'friendly',
#   'perfect',
#   'love',
#   'nice',
#   'tasty'])

# %%
all_words = " ".join(df["cleaned_review"]).split()
word_counts = Counter(all_words)
all_words,word_counts
# Out:
# (['excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'great',
#   'food',
#   'and',
#   'service',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'great',
#   'food',
#   'and',
#   'service',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'great',
#   'food',
#   'and',
#   'service',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'great',
#   'food',
#   'and',
#   'service',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'great',
#   'food',
#   'and',
#   'service',
#   'great',
#   'food',
#   'and',
#   'service',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'great',
#   'food',
#   'and',
#   'service',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'great',
#   'food',
#   'and',
#   'service',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'great',
#   'food',
#   'and',
#   'service',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'great',
#   'food',
#   'and',
#   'service',
#   'great',
#   'food',
#   'and',
#   'service',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'great',
#   'food',
#   'and',
#   'service',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'great',
#   'food',
#   'and',
#   'service',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'great',
#   'food',
#   'and',
#   'service',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'great',
#   'food',
#   'and',
#   'service',
#   'great',
#   'food',
#   'and',
#   'service',
#   'great',
#   'food',
#   'and',
#   'service',
#   'great',
#   'food',
#   'and',
#   'service',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'great',
#   'food',
#   'and',
#   'service',
#   'great',
#   'food',
#   'and',
#   'service',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'great',
#   'food',
#   'and',
#   'service',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'great',
#   'food',
#   'and',
#   'service',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'excellent',
#   'taste',
#   'and',
#   'friendly',
#   'staff',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'great',
#   'food',
#   'and',
#   'service',
#   'average',
#   'experience',
#   'nothing',
#   'special',
#   'will',
#   'definitely',
#   'come',
#   'back',
#   'again',
#   'great',
#   'food',
#   'and',
#   'service',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'food',
#   'was',
#   'cold',
#   'and',
#   'service',
#   'was',
#   'slow',
#   'excellent',
#   'taste',
#   'and',
#   ...],
#  Counter({'and': 5713,
#           'was': 3854,
#           'food': 3834,
#           'service': 3834,
#           'cold': 1927,
#           'slow': 1927,
#           'will': 1923,
#           'definitely': 1923,
#           'come': 1923,
#           'back': 1923,
#           'again': 1923,
#           'average': 1915,
#           'experience': 1915,
#           'nothing': 1915,
#           'special': 1915,
#           'great': 1907,
#           'excellent': 1879,
#           'taste': 1879,
#           'friendly': 1879,
#           'staff': 1879}))

# %%
positive_counts = {word: word_counts[word] for word in positive_words if word in word_counts}
negative_counts = {word: word_counts[word] for word in negative_words if word in word_counts}
positive_counts
# Out:
# {'great': 1907, 'excellent': 1879, 'friendly': 1879}

# %%
negative_counts
# Out:
# {'slow': 1927}

# %%
df["review_length"] = df["cleaned_review"].apply(lambda x: len(x.split()))
avg_length = df["review_length"].mean()
avg_length
# Out:
# 5.003350434509476

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df["review_length"], df[rating_col], alpha=0.5)
plt.title("Review Length vs. Rating")
plt.xlabel("Review Length (words)")
plt.ylabel("Rating")
plt.grid(True)
plt.show()

# %%
print("Most Common Positive Keywords:", positive_counts)
print("Most Common Negative Keywords:", negative_counts)
print(f"Average Review Length: {avg_length:.2f} words")
# Out:
# Most Common Positive Keywords: {'great': 1907, 'excellent': 1879, 'friendly': 1879}
# Most Common Negative Keywords: {'slow': 1927}
# Average Review Length: 5.00 words

# %%
name_col = "Restaurant Name"     
votes_col = "Votes"               
rating_col = "Aggregate rating"

# %%
name_col
# Out:
# 'Restaurant Name'

# %%
for col in [name_col, votes_col, rating_col]:
    if col not in df.columns:
        raise ValueError(f"The dataset does not contain a '{col}' column.")

# %%
highest_votes = df.loc[df[votes_col].idxmax()]
lowest_votes = df.loc[df[votes_col].idxmin()]
highest_votes
# Out:
# Restaurant ID                                                       51705
# Restaurant Name                                                      Toit
# Country Code                                                            1
# City                                                            Bangalore
# Address                 298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# Locality                                                      Indiranagar
# Locality Verbose                                   Indiranagar, Bangalore
# Longitude                                                       77.640709
# Latitude                                                        12.979166
# Cuisines                                         Italian, American, Pizza
# Average Cost for two                                                 2000
# Currency                                               Indian Rupees(Rs.)
# Has Table booking                                                      No
# Has Online delivery                                                    No
# Is delivering now                                                      No
# Switch to order menu                                                   No
# Price range                                                             4
# Aggregate rating                                                      4.8
# Rating color                                                   Dark Green
# Rating text                                                     Excellent
# Votes                                                               10934
# Review                                   Will definitely come back again!
# cleaned_review                            will definitely come back again
# review_length                                                           5
# Name: 728, dtype: object

# %%
lowest_votes
# Out:
# Restaurant ID                                                     6710645
# Restaurant Name                                          Cantinho da Gula
# Country Code                                                           30
# City                                                           S��o Paulo
# Address                 Rua Pedroso Alvarenga, 522, Itaim Bibi, S��o P...
# Locality                                                       Itaim Bibi
# Locality Verbose                                   Itaim Bibi, S��o Paulo
# Longitude                                                      -46.675667
# Latitude                                                          -23.581
# Cuisines                                                        Brazilian
# Average Cost for two                                                   55
# Currency                                               Brazilian Real(R$)
# Has Table booking                                                      No
# Has Online delivery                                                    No
# Is delivering now                                                      No
# Switch to order menu                                                   No
# Price range                                                             2
# Aggregate rating                                                      0.0
# Rating color                                                        White
# Rating text                                                     Not rated
# Votes                                                                   0
# Name: 69, dtype: object

# %%
correlation = df[[votes_col, rating_col]].corr().iloc[0, 1]
correlation
# Out:
# 0.31369058419540996

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[votes_col], df[rating_col], alpha=0.5, color='yellow', edgecolors='black')
plt.title("Votes vs Rating")
plt.xlabel("Number of Votes")
plt.ylabel("Rating")
plt.grid(True)
plt.show()

# %%
print("Restaurant with highest votes:")
print(highest_votes, "\n")
print("Restaurant with lowest votes:")
print(lowest_votes, "\n")
print(f"Correlation between number of votes and rating: {correlation:.2f}")
# Out:
# Restaurant with highest votes:
# Restaurant ID                                                       51705
# Restaurant Name                                                      Toit
# Country Code                                                            1
# City                                                            Bangalore
# Address                 298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# Locality                                                      Indiranagar
# Locality Verbose                                   Indiranagar, Bangalore
# Longitude                                                       77.640709
# Latitude                                                        12.979166
# Cuisines                                         Italian, American, Pizza
# Average Cost for two                                                 2000
# Currency                                               Indian Rupees(Rs.)
# Has Table booking                                                      No
# Has Online delivery                                                    No
# Is delivering now                                                      No
# Switch to order menu                                                   No
# Price range                                                             4
# Aggregate rating                                                      4.8
# Rating color                                                   Dark Green
# Rating text                                                     Excellent
# Votes                                                               10934
# Review                                   Will definitely come back again!
# cleaned_review                            will definitely come back again
# review_length                                                           5
# Name: 728, dtype: object
#
# Restaurant with lowest votes:
# Restaurant ID                                                     6710645
# Restaurant Name                                          Cantinho da Gula
# Country Code                                                           30
# City                                                           S��o Paulo
# Address                 Rua Pedroso Alvarenga, 522, Itaim Bibi, S��o P...
# Locality                                                       Itaim Bibi
# Locality Verbose                                   Itaim Bibi, S��o Paulo
# Longitude                                                      -46.675667
# Latitude                                                          -23.581
# Cuisines                                                        Brazilian
# Average Cost for two                                                   55
# Currency                                               Brazilian Real(R$)
# Has Table booking                                                      No
# Has Online delivery                                                    No
# Is delivering now                                                      No
# Switch to order menu                                                   No
# Price range                                                             2
# Aggregate rating                                                      0.0
# Rating color                                                        White
# Rating text                                                     Not rated
# Votes                                                                   0
# Review                                            Great food and service!
# cleaned_review                                     great food and service
# review_length                                                           4
# Name: 69, dtype: object
#
# Correlation between number of votes and rating: 0.31

# %%
price_col = "Price range"           
delivery_col = "Has Online delivery"
booking_col = "Has Table booking"

# %%
price_col
# Out:
# 'Price range'

# %%
for col in [price_col, delivery_col, booking_col]:
    if col not in df.columns:
        raise ValueError(f"The dataset does not contain a '{col}' column.")

# %%
price_analysis = df.groupby(price_col).agg({
    delivery_col: lambda x: (x == "Yes").mean() * 100,
    booking_col: lambda x: (x == "Yes").mean() * 100
}).rename(columns={
    delivery_col: "% Offering Online Delivery",
    booking_col: "% Offering Table Booking"
})

# %%
price_analysis
# Out:
#              % Offering Online Delivery  % Offering Table Booking
# Price range
# 1                             15.774077                  0.022502
# 2                             41.310633                  7.677482
# 3                             29.190341                 45.738636
# 4                              9.044369                 46.757679

# %%
print(price_analysis.round(2))
# Out:
#              % Offering Online Delivery  % Offering Table Booking
# Price range
# 1                                 15.77                      0.02
# 2                                 41.31                      7.68
# 3                                 29.19                     45.74
# 4                                  9.04                     46.76

# %%
price_analysis.plot(kind='bar', figsize=(8, 5))
plt.title("Services Availability by Price Range")
plt.ylabel("Percentage of Restaurants")
plt.xlabel("Price Range")
plt.xticks(rotation=0)
plt.legend(title="Service")
plt.grid(axis='y')
plt.show()
